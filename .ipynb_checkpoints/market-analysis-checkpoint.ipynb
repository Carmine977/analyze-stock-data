# %% [markdown]
# ## Market Analysis

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.util import get_data, plot_data, compute_daily_returns, fit_scatter, compute_sharpe_ratio
# %matplotlib inline

# %% [markdown]
# ### Initializations

# %%
date_start = '2016-01-01'
date_end = '2017-07-08'

# NYSE – Most Active Stocks
symbols = ['BAC', 'RAD', 'GE', 'CHK', 'WFT', 'ABEV', 'WLL', 'VALE', 'AKS', 
             'X', 'ESV', 'F', 'T', 'CX', 'VRX', 'PBR', 'ITUB', 'SWN', 'PFE', 'MRO']

dates = pd.date_range(date_start, date_end)

# %% [markdown]
# ### Load and plot stock data

# %%
df = get_data(symbols, dates, price='Close', folder='historical data')

# normalize all stock prices
df_n = df / df.ix[0]

# plot stocks prices
plot_data(df_n)

# %% [markdown]
# ### Compute statistics

# %%
# Compute cumulative ruturn (from beginning to end)
cum_ret = df_n.ix[-1] - df_n.ix[0]

# Compute daily return, mean and standard deviation (volatility)
daily_returns = compute_daily_returns(df)
avg_daily_ret = daily_returns.mean()
std_daily_ret = daily_returns.std()

# Compute sharp ratio
sharpe_ratio = compute_sharpe_ratio(df)

# Group statistics
stat = pd.concat([cum_ret, avg_daily_ret, std_daily_ret, sharpe_ratio], 
          keys=['cum_ret', 'avg_daily_ret', 'std_daily_ret', 'sharpe_ratio'],axis=1)

# %%
plt.figure(figsize=(10,6))
plt.plot(avg_daily_ret, std_daily_ret, 'o')
plt.xlabel('avg_daily_ret')
plt.ylabel('std_daily_ret')
plt.grid()
plt.show()

# %%
# Show statistics sorted by sharp ratio
stat.sort_values(['sharpe_ratio'], ascending=False)
# Out:
#        cum_ret  avg_daily_ret  std_daily_ret  sharpe_ratio
# VALE  1.775316       0.003542       0.041708      1.348165
# X     1.635135       0.003613       0.046159      1.242444
# AKS   1.531915       0.003392       0.043928      1.225885
# CX    0.885277       0.002098       0.029393      1.132991
# SPY   0.204408       0.000514       0.007213      1.131845
# BAC   0.511260       0.001256       0.018515      1.076723
# ITUB  0.763666       0.001918       0.029176      1.043618
# PBR   0.816901       0.002308       0.038604      0.948954
# ABEV  0.276347       0.000822       0.019012      0.686385
# T     0.076565       0.000234       0.008977      0.413734
# CHK  -0.082828       0.001477       0.058706      0.399454
# PFE   0.043818       0.000168       0.010547      0.252233
# MRO  -0.105304       0.000392       0.037299      0.167033
# SWN  -0.273671       0.000216       0.046171      0.074326
# WLL  -0.477440      -0.000040       0.058137     -0.010810
# WFT  -0.591435      -0.001258       0.047106     -0.423817
# F    -0.193987      -0.000446       0.015434     -0.458886
# GE   -0.148486      -0.000369       0.010327     -0.566524
# VRX  -0.835228      -0.002818       0.059058     -0.757362
# ESV  -0.699811      -0.002256       0.042801     -0.836544
# RAD  -0.700000      -0.002573       0.033825     -1.207342

# %% [markdown]
# ### Perform visual check

# %%
stock = 'GE'

# Compute daily returns
daily_returns = compute_daily_returns(df)

# %%
plot_data(df_n[['SPY', stock]])

# %% [markdown]
# * **Daily Returns**

# %%
plot_data(daily_returns[['SPY', stock]], title="Daily Returns")

# %% [markdown]
# * **Scatter Plot**

# %%
fit_scatter(daily_returns, x='SPY', y=stock)
# Out:
# beta= 0.951388249345
# alpha= -0.000857806771084

# %%
correl = daily_returns.corr(method='pearson')
correl['SPY'].sort_values(ascending=False)
# Out:
# SPY     1.000000
# BAC     0.696446
# GE      0.664481
# CX      0.630117
# F       0.602117
# PBR     0.496116
# VALE    0.492806
# ABEV    0.469553
# PFE     0.462596
# MRO     0.452161
# X       0.452032
# ITUB    0.450337
# WLL     0.423807
# WFT     0.408327
# AKS     0.398996
# T       0.384978
# ESV     0.380431
# CHK     0.356819
# SWN     0.265609
# VRX     0.182083
# RAD     0.164783
# Name: SPY, dtype: float64
